# %% [markdown]
# <a href="https://colab.research.google.com/github/samiksha22122/leetcode/blob/main/Pandas_leetcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A country is big if:
# # it has an area of at least three million (i.e., 3000000 km2), or
# # it has a population of at least twenty-five million (i.e., 25000000).
# # Write a solution to find the name, population, and area of the big countries.

# %%
import pandas as pd
data = {
    "name": ["Afghanistan", "Albania", "Algeria", "Andorra", "Angola"],
    "continent": ["Asia", "Europe", "Africa", "Europe", "Africa"],
    "area": [652230, 28748, 2381741, 468, 1246700],
    "population": [25500100, 2831741, 37100000, 78115, 20609294],
    "gdp": [20343000000, 12960000000, 188681000000, 3712000000, 100990000000]
}

df=pd.DataFrame(data)
df
# Out:
#           name continent     area  population           gdp
# 0  Afghanistan      Asia   652230    25500100   20343000000
# 1      Albania    Europe    28748     2831741   12960000000
# 2      Algeria    Africa  2381741    37100000  188681000000
# 3      Andorra    Europe      468       78115    3712000000
# 4       Angola    Africa  1246700    20609294  100990000000

# %%
df.query('area>=3000000 or population>=25000000')[['name','population','area']]
# Out:
#           name  population     area
# 0  Afghanistan    25500100   652230
# 2      Algeria    37100000  2381741

# %% [markdown]
# #Write a solution to find the ids of products that are both low fat and recyclable.

# %%
table_schema =  {
    "product_id": [0, 1, 2, 3, 4],
    "low_fats": ["Y", "Y", "N", "Y", "N"],
    "recyclable": ["N", "Y", "Y", "Y", "N"]
}
df=pd.DataFrame(table_schema)

# %%
df
# Out:
#    product_id low_fats recyclable
# 0           0        Y          N
# 1           1        Y          Y
# 2           2        N          Y
# 3           3        Y          Y
# 4           4        N          N

# %%
import numpy as np

# %%
np.where((df['low_fats']=='Y') & (df['recyclable']=='Y'))
# Out:
# (array([1, 3]),)

# %% [markdown]
# #Write a solution to find all customers who never order anything.

# %%
customers = pd.DataFrame({
    "id": [1, 2, 3, 4],
    "name": ["Joe", "Henry", "Sam", "Max"]
})
orders = pd.DataFrame({
    "id": [1, 2],
    "customerId": [3, 1]
})

# %%
customers
# Out:
#    id   name
# 0   1    Joe
# 1   2  Henry
# 2   3    Sam
# 3   4    Max

# %%
orders
# Out:
#    id  customerId
# 0   1           3
# 1   2           1

# %%
merged_df=customers.merge(orders, left_on="id", right_on="customerId", how="left")
# Out:
#    id_x   name  id_y  customerId
# 0     1    Joe   2.0         1.0
# 1     2  Henry   NaN         NaN
# 2     3    Sam   1.0         3.0
# 3     4    Max   NaN         NaN

# %%
merged_df
# Out:
#    id_x   name  id_y  customerId
# 0     1    Joe   2.0         1.0
# 1     2  Henry   NaN         NaN
# 2     3    Sam   1.0         3.0
# 3     4    Max   NaN         NaN

# %%
never_ordered = merged_df[merged_df["customerId"].isna()][["id_x", "name"]]
never_ordered
# Out:
#    id_x   name
# 1     2  Henry
# 3     4    Max

# %% [markdown]
# #Write a solution to find all the authors that viewed at least one of their own articles.

# %%
import pandas as pd

# %%
article_views = pd.DataFrame({
    "article_id": [1, 1, 2, 2, 4, 3, 3],
    "author_id": [3, 3, 7, 7, 7, 4, 4],
    "viewer_id": [5, 6, 7, 6, 1, 4, 4],
    "view_date": ["2019-08-01", "2019-08-02", "2019-08-01", "2019-08-02", "2019-07-22", "2019-07-21", "2019-07-21"]
})
article_views
# Out:
#    article_id  author_id  viewer_id   view_date
# 0           1          3          5  2019-08-01
# 1           1          3          6  2019-08-02
# 2           2          7          7  2019-08-01
# 3           2          7          6  2019-08-02
# 4           4          7          1  2019-07-22
# 5           3          4          4  2019-07-21
# 6           3          4          4  2019-07-21

# %%
article_views.drop_duplicates(inplace=True)

# %%
article_views
# Out:
#    article_id  author_id  viewer_id   view_date
# 0           1          3          5  2019-08-01
# 1           1          3          6  2019-08-02
# 2           2          7          7  2019-08-01
# 3           2          7          6  2019-08-02
# 4           4          7          1  2019-07-22
# 5           3          4          4  2019-07-21

# %%
article_views[article_views["author_id"] == article_views["viewer_id"]]['author_id'].sort_values()
# Out:
# 5    4
# 2    7
# Name: author_id, dtype: int64

# %% [markdown]
# #Write a solution to find the IDs of the invalid tweets. The tweet is invalid if the number of characters used in the content of the tweet is strictly greater than 15.

# %%
tweets = pd.DataFrame({
    "tweet_id": [1, 2],
    "content": ["Let us Code", "More than fifteen chars are here!"]
})
tweets
# Out:
#    tweet_id                            content
# 0         1                        Let us Code
# 1         2  More than fifteen chars are here!

# %%
tweets[tweets["content"].str.len() > 15]["tweet_id"]
# Out:
# 1    2
# Name: tweet_id, dtype: int64

# %% [markdown]
# #Write a solution to calculate the bonus of each employee. The bonus of an employee is 100% of their salary if the ID of the employee is an odd number and the employee's name does not start with the character 'M'. The bonus of an employee is 0 otherwise.

# %%
employees = {
    "employee_id": [2, 3, 7, 8, 9],
    "name": ["Meir", "Michael", "Addilyn", "Juan", "Kannon"],
    "salary": [3000, 3800, 7400, 6100, 7700]
}

df = pd.DataFrame(employees)
df
# Out:
#    employee_id     name  salary
# 0            2     Meir    3000
# 1            3  Michael    3800
# 2            7  Addilyn    7400
# 3            8     Juan    6100
# 4            9   Kannon    7700

# %%
df["bonus"] = df["salary"] * ((df["employee_id"] % 2 == 1) &  (~df["name"].str.startswith("M")))

# %%
df
# Out:
#    employee_id     name  salary  bonus
# 0            2     Meir    3000      0
# 1            3  Michael    3800      0
# 2            7  Addilyn    7400   7400
# 3            8     Juan    6100      0
# 4            9   Kannon    7700   7700

# %% [markdown]
# #Write a solution to fix the names so that only the first character is uppercase and the rest are lowercase.

# %%
f = pd.DataFrame({
    "user_id": [1, 2],
    "name": ["aLice", "bOB"]
})
f
# Out:
#    user_id   name
# 0        1  aLice
# 1        2    bOB

# %%
f['name'].str.title()
# Out:
# 0    Alice
# 1      Bob
# Name: name, dtype: object

# %% [markdown]
# ###Write a solution to find the users who have valid emails.
#
# A valid e-mail has a prefix name and a domain where:
#
# The prefix name is a string that may contain letters (upper or lower case), digits, underscore '_', period '.', and/or dash '-'. The prefix name must start with a letter.
# The domain is '@leetcode.com'.

# %%
df = pd.DataFrame({
    "user_id": [1, 2, 3, 4, 5, 6, 7],
    "name": ["Winston", "Jonathan", "Annabelle", "Sally", "Marwan", "David", "Shapiro"],
    "mail": [
        "winston@leetcode.com",
        "jonathanisgreat",
        "bella-@leetcode.com",
        "sally.come@leetcode.com",
        "quarz#2020@leetcode.com",
        "david69@gmail.com",
        ".shapo@leetcode.com"
    ]
})
df
# Out:
#    user_id       name                     mail
# 0        1    Winston     winston@leetcode.com
# 1        2   Jonathan          jonathanisgreat
# 2        3  Annabelle      bella-@leetcode.com
# 3        4      Sally  sally.come@leetcode.com
# 4        5     Marwan  quarz#2020@leetcode.com
# 5        6      David        david69@gmail.com
# 6        7    Shapiro      .shapo@leetcode.com

# %%
valid_email_pattern = r'^[a-zA-Z][a-zA-Z0-9._-]*@leetcode\.com$'
df[df['mail'].str.match(valid_email_pattern, na=False)]
# Out:
#    user_id       name                     mail
# 0        1    Winston     winston@leetcode.com
# 2        3  Annabelle      bella-@leetcode.com
# 3        4      Sally  sally.come@leetcode.com

# %% [markdown]
# #Write a solution to find the patient_id, patient_name, and conditions of the patients who have Type I Diabetes. Type I Diabetes always starts with DIAB1 prefix.

# %%
df = pd.DataFrame({
    "patient_id": [1, 2, 3, 4, 5],
    "patient_name": ["Daniel", "Alice", "Bob", "George", "Alain"],
    "conditions": ["YFEV COUGH", "", "DIAB100 MYOP", "ACNE DIAB100", "DIAB201"]
})
df
# Out:
#    patient_id patient_name    conditions
# 0           1       Daniel    YFEV COUGH
# 1           2        Alice
# 2           3          Bob  DIAB100 MYOP
# 3           4       George  ACNE DIAB100
# 4           5        Alain       DIAB201

# %%
df[df['conditions'].str.contains(r'DIAB1')]
# Out:
#    patient_id patient_name    conditions
# 2           3          Bob  DIAB100 MYOP
# 3           4       George  ACNE DIAB100

# %% [markdown]
# #Write a solution to find employees who have the highest salary in each of the departments.

# %%
import pandas as pd

# %%
emp_df = pd.DataFrame({
    "id": [1, 2, 3, 4, 5],
    "name": ["Joe", "Jim", "Henry", "Sam", "Max"],
    "salary": [70000, 90000, 80000, 60000, 90000],
    "departmentId": [1, 1, 2, 2, 1]
})
emp_df
# Out:
#    id   name  salary  departmentId
# 0   1    Joe   70000             1
# 1   2    Jim   90000             1
# 2   3  Henry   80000             2
# 3   4    Sam   60000             2
# 4   5    Max   90000             1

# %%
department_df = pd.DataFrame({
    "id": [1, 2],
    "name": ["IT", "Sales"]
})
department_df = department_df.rename(columns={"id": "departmentId", "name": "department_name"})
department_df
# Out:
#    departmentId department_name
# 0             1              IT
# 1             2           Sales

# %%
v=emp_df.merge(department_df,left_on='departmentId',right_on='departmentId')
v
# Out:
#    id   name  salary  departmentId department_name
# 0   1    Joe   70000             1              IT
# 1   2    Jim   90000             1              IT
# 2   3  Henry   80000             2           Sales
# 3   4    Sam   60000             2           Sales
# 4   5    Max   90000             1              IT

# %%
s=v.groupby('department_name')['salary'].max().reset_index()
s
# Out:
#   department_name  salary
# 0              IT   90000
# 1           Sales   80000

# %%
s.merge(emp_df,how='inner')
# Out:
#   department_name  salary  id   name  departmentId
# 0              IT   90000   2    Jim             1
# 1              IT   90000   5    Max             1
# 2           Sales   80000   3  Henry             2

# %% [markdown]
# #Write a solution to delete all duplicate emails, keeping only one unique email with the smallest id.

# %%
import pandas as pd
df = pd.DataFrame({
    "id": [1, 2, 3],
    "email": ["john@example.com", "bob@example.com", "john@example.com"]
})

# %%
df
# Out:
#    id             email
# 0   1  john@example.com
# 1   2   bob@example.com
# 2   3  john@example.com

# %%
df.drop_duplicates(subset='email',keep='first')
# Out:
#    id             email
# 0   1  john@example.com
# 1   2   bob@example.com

# %% [markdown]
# ##Write a solution to rearrange the Products table so that each row has (product_id, store, price). If a product is not available in a store, do not include a row with that product_id and store combination in the result table.

# %%
import numpy as np
import pandas as pd

# %%
data = {
    "product_id": [0, 1],
    "store1": [95, 70],
    "store2": [100, np.nan],
    "store3": [105, 80]
}

df = pd.DataFrame(data)
df
# Out:
#    product_id  store1  store2  store3
# 0           0      95   100.0     105
# 1           1      70     NaN      80

# %%
df_long = df.melt(id_vars=["product_id"], var_name="store", value_name="price").dropna()
df_long
# Out:
#    product_id   store  price
# 0           0  store1   95.0
# 1           1  store1   70.0
# 2           0  store2  100.0
# 4           0  store3  105.0
# 5           1  store3   80.0

# %% [markdown]
# ##Write a solution to calculate the total time in minutes spent by each employee on each day at the office. Note that within one day, an employee can enter and leave more than once. The time spent in the office for a single entry is out_time - in_time.

# %%
data = {
    "emp_id": [1, 1, 1, 2, 2],
    "event_day": ["2020-11-28", "2020-11-28", "2020-12-03", "2020-11-28", "2020-12-09"],
    "in_time": [4, 55, 1, 3, 47],
    "out_time": [32, 200, 42, 33, 74]
}

df = pd.DataFrame(data)
df
# Out:
#    emp_id   event_day  in_time  out_time
# 0       1  2020-11-28        4        32
# 1       1  2020-11-28       55       200
# 2       1  2020-12-03        1        42
# 3       2  2020-11-28        3        33
# 4       2  2020-12-09       47        74

# %%
df['event_day']=pd.to_datetime(df['event_day'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   emp_id     5 non-null      int64
#  1   event_day  5 non-null      datetime64[ns]
#  2   in_time    5 non-null      int64
#  3   out_time   5 non-null      int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 292.0 bytes

# %%
df['time']=df['out_time']-df['in_time']

# %%
df
# Out:
#    emp_id  event_day  in_time  out_time  time
# 0       1 2020-11-28        4        32    28
# 1       1 2020-11-28       55       200   145
# 2       1 2020-12-03        1        42    41
# 3       2 2020-11-28        3        33    30
# 4       2 2020-12-09       47        74    27

# %%
v=df.groupby(['event_day','emp_id']).sum()['time'].reset_index()
pd.DataFrame(v)
# Out:
#    event_day  emp_id  time
# 0 2020-11-28       1   173
# 1 2020-11-28       2    30
# 2 2020-12-03       1    41
# 3 2020-12-09       2    27

# %%
df.groupby(["emp_id", "event_day"])["time"].sum().reset_index()
# Out:
#    emp_id  event_day  time
# 0       1 2020-11-28   173
# 1       1 2020-12-03    41
# 2       2 2020-11-28    30
# 3       2 2020-12-09    27

# %% [markdown]
# #Write a solution to find the first login date for each player.

# %%
data = {
    "player_id": [1, 1, 2, 3, 3],
    "device_id": [2, 2, 3, 1, 4],
    "event_date": ["2016-03-01", "2016-05-02", "2017-06-25", "2016-03-02", "2018-07-03"],
    "games_played": [5, 6, 1, 0, 5]
}

df = pd.DataFrame(data)
df['event_date']=pd.to_datetime(df['event_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   player_id     5 non-null      int64
#  1   device_id     5 non-null      int64
#  2   event_date    5 non-null      datetime64[ns]
#  3   games_played  5 non-null      int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 292.0 bytes

# %%
df
# Out:
#    player_id  device_id event_date  games_played
# 0          1          2 2016-03-01             5
# 1          1          2 2016-05-02             6
# 2          2          3 2017-06-25             1
# 3          3          1 2016-03-02             0
# 4          3          4 2018-07-03             5

# %%
df.drop_duplicates(subset='player_id')
# Out:
#    player_id  device_id event_date  games_played
# 0          1          2 2016-03-01             5
# 2          2          3 2017-06-25             1
# 3          3          1 2016-03-02             0

# %% [markdown]
# or

# %%
df.groupby('player_id')['event_date'].min().reset_index()
# Out:
#    player_id event_date
# 0          1 2016-03-01
# 1          2 2017-06-25
# 2          3 2016-03-02

# %% [markdown]
# #Write a solution to calculate the number of unique subjects each teacher teaches in the university.

# %%
data = {
    "teacher_id": [1, 1, 1, 2, 2, 2, 2],
    "subject_id": [2, 2, 3, 1, 2, 3, 4],
    "dept_id": [3, 4, 3, 1, 1, 1, 1]
}

df = pd.DataFrame(data)
df
# Out:
#    teacher_id  subject_id  dept_id
# 0           1           2        3
# 1           1           2        4
# 2           1           3        3
# 3           2           1        1
# 4           2           2        1
# 5           2           3        1
# 6           2           4        1

# %%
df.groupby('teacher_id')['subject_id'].nunique().reset_index()
# Out:
#    teacher_id  subject_id
# 0           1           2
# 1           2           4

# %% [markdown]
# #Write a solution to find all the classes that have at least five students.

# %%
data = {
    "student": ["A", "B", "C", "D", "E", "F", "G", "H", "I"],
    "class": ["Math", "English", "Math", "Biology", "Math", "Computer", "Math", "Math", "Math"]
}

df = pd.DataFrame(data)
df
# Out:
#   student     class
# 0       A      Math
# 1       B   English
# 2       C      Math
# 3       D   Biology
# 4       E      Math
# 5       F  Computer
# 6       G      Math
# 7       H      Math
# 8       I      Math

# %%
v=df.groupby('class')['student'].count()

# %%
v[v>=5].reset_index()['class']
# Out:
# 0    Math
# Name: class, dtype: object

# %% [markdown]
# #Write a solution to find the customer_number for the customer who has placed the largest number of orders.

# %%
data = {
    "order_number": [1, 2, 3, 4],
    "customer_number": [1, 2, 3, 3]
}

df = pd.DataFrame(data)
df
# Out:
#    order_number  customer_number
# 0             1                1
# 1             2                2
# 2             3                3
# 3             4                3

# %%
df.groupby('customer_number')['order_number'].sum().idxmax()
# Out:
# 3

# %% [markdown]
# #Write a solution to find for each date the number of different products sold and their names. The sold products names for each date should be sorted lexicographically.

# %%
data = {
    "sell_date": ["2020-05-30", "2020-06-01", "2020-06-02", "2020-05-30", "2020-06-01", "2020-06-02", "2020-05-30"],
    "product": ["Headphone", "Pencil", "Mask", "Basketball", "Bible", "Mask", "T-Shirt"]
}

df = pd.DataFrame(data)
df
# Out:
#     sell_date     product
# 0  2020-05-30   Headphone
# 1  2020-06-01      Pencil
# 2  2020-06-02        Mask
# 3  2020-05-30  Basketball
# 4  2020-06-01       Bible
# 5  2020-06-02        Mask
# 6  2020-05-30     T-Shirt

# %%
b=df.groupby('sell_date')['product'].count().reset_index()

# %%
b
# Out:
#     sell_date  product
# 0  2020-05-30        3
# 1  2020-06-01        2
# 2  2020-06-02        2

# %%
v=df.groupby('sell_date')['product'].apply(lambda x: sorted(x.unique())).reset_index()

# %%
v
# Out:
#     sell_date                           product
# 0  2020-05-30  [Basketball, Headphone, T-Shirt]
# 1  2020-06-01                   [Bible, Pencil]
# 2  2020-06-02                            [Mask]

# %%
v["unique_product_count"] = v["product"].apply(len)

# %%
v
# Out:
#     sell_date                           product  unique_product_count
# 0  2020-05-30  [Basketball, Headphone, T-Shirt]                     3
# 1  2020-06-01                   [Bible, Pencil]                     2
# 2  2020-06-02                            [Mask]                     1

# %%
v.columns = ["sell_date", "product_names", "unique_product_count"]
v
# Out:
#     sell_date                     product_names  unique_product_count
# 0  2020-05-30  [Basketball, Headphone, T-Shirt]                     3
# 1  2020-06-01                   [Bible, Pencil]                     2
# 2  2020-06-02                            [Mask]                     1

# %% [markdown]
# #For each date_id and make_name, find the number of distinct lead_id's and distinct partner_id's.

# %%
data = {
    "date_id": ["2020-12-8", "2020-12-8", "2020-12-8", "2020-12-7", "2020-12-7",
                "2020-12-8", "2020-12-8", "2020-12-7", "2020-12-7", "2020-12-7"],
    "make_name": ["toyota", "toyota", "toyota", "toyota", "toyota",
                  "honda", "honda", "honda", "honda", "honda"],
    "lead_id": [0, 1, 1, 0, 0, 1, 2, 0, 1, 2],
    "partner_id": [1, 0, 2, 2, 1, 2, 1, 1, 2, 1]
}

df = pd.DataFrame(data)
df
# Out:
#      date_id make_name  lead_id  partner_id
# 0  2020-12-8    toyota        0           1
# 1  2020-12-8    toyota        1           0
# 2  2020-12-8    toyota        1           2
# 3  2020-12-7    toyota        0           2
# 4  2020-12-7    toyota        0           1
# 5  2020-12-8     honda        1           2
# 6  2020-12-8     honda        2           1
# 7  2020-12-7     honda        0           1
# 8  2020-12-7     honda        1           2
# 9  2020-12-7     honda        2           1

# %%
df.groupby(['date_id','make_name'])[['lead_id','partner_id']].nunique().reset_index()
# Out:
#      date_id make_name  lead_id  partner_id
# 0  2020-12-7     honda        3           2
# 1  2020-12-7    toyota        1           2
# 2  2020-12-8     honda        2           2
# 3  2020-12-8    toyota        2           3

# %% [markdown]
# #Write a solution to find all the pairs (actor_id, director_id) where the actor has cooperated with the director at least three times.

# %%
data = {
    "actor_id": [1, 1, 1, 1, 1, 2, 2],
    "director_id": [1, 1, 1, 2, 2, 1, 1],
    "timestamp": [0, 1, 2, 3, 4, 5, 6]
}

df = pd.DataFrame(data)
df
# Out:
#    actor_id  director_id  timestamp
# 0         1            1          0
# 1         1            1          1
# 2         1            1          2
# 3         1            2          3
# 4         1            2          4
# 5         2            1          5
# 6         2            1          6

# %%
d=df.groupby(['actor_id','director_id']).filter
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-183-047c66b6dffe> in <cell line: 0>()
# ----> 1 d=df.groupby(['actor_id','director_id']).filter(lambda x:x)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/generic.py in filter(self, func, dropna, *args, **kwargs)
#    1930             else:
#    1931                 # non scalars aren't allowed
# -> 1932                 raise TypeError(
#    1933                     f"filter function returned a {type(res).__name__}, "
#    1934                     "but expected a scalar bool"
#
# TypeError: filter function returned a DataFrame, but expected a scalar bool

# %%
d[d>=3].reset_index()
# Out:
#    actor_id  director_id  timestamp
# 0         1            1        3.0
# 1         1            2        NaN
# 2         2            1        NaN

# %%
df.groupby(["actor_id", "director_id"]).filter(lambda x: len(x) >= 3)[["actor_id", "director_id"]].drop_duplicates()
# Out:
#    actor_id  director_id
# 0         1            1

# %%
# .filter(lambda x: len(x) >= 3)

# The filter() function keeps only those groups where the count of rows is 3 or more.
# The lambda x: len(x) >= 3 checks the number of times an actor-director pair appears in the dataset.
# [["actor_id", "director_id"]]

# After filtering, we only select the actor_id and director_id columns.
# .drop_duplicates()

# Since multiple rows may exist for a valid pair, we remove duplicates to show each pair only once.

# %% [markdown]
# #Write a solution to show the unique ID of each user, If a user does not have a unique ID replace just show null.

# %%
df1 = pd.DataFrame({
    "id": [1, 7, 11, 90, 3],
    "name": ["Alice", "Bob", "Meir", "Winston", "Jonathan"]
})

# Second DataFrame
df2 = pd.DataFrame({
    "id": [3, 11, 90],
    "unique_id": [1, 2, 3]
})
df1
# Out:
#    id      name
# 0   1     Alice
# 1   7       Bob
# 2  11      Meir
# 3  90   Winston
# 4   3  Jonathan

# %%
df2
# Out:
#    id  unique_id
# 0   3          1
# 1  11          2
# 2  90          3

# %%
df1.merge(df2,how='left')[['name','unique_id']].replace(np.nan,'null')
# Out:
#        name unique_id
# 0     Alice      null
# 1       Bob      null
# 2      Meir       2.0
# 3   Winston       3.0
# 4  Jonathan       1.0

# %% [markdown]
# #Write a solution to find the number of times each student attended each exam Return the result table ordered by student_id and subject_name.

# %%
students_df = pd.DataFrame({
    "student_id": [1, 2, 13, 6],
    "student_name": ["Alice", "Bob", "John", "Alex"]
})

# Second DataFrame: Subjects
subjects_df = pd.DataFrame({
    "subject_name": ["Math", "Physics", "Programming"]
})

# %%
students_df
# Out:
#    student_id student_name
# 0           1        Alice
# 1           2          Bob
# 2          13         John
# 3           6         Alex

# %%
subjects_df
# Out:
#   subject_name
# 0         Math
# 1      Physics
# 2  Programming

# %%
student_subject_df = pd.DataFrame({
    "student_id": [1, 1, 1, 2, 1, 1, 13, 13, 13, 2, 1],
    "subject_name": [
        "Math", "Physics", "Programming", "Programming", "Physics", "Math",
        "Math", "Programming", "Physics", "Math", "Math"
    ]
})

student_subject_df
# Out:
#     student_id subject_name
# 0            1         Math
# 1            1      Physics
# 2            1  Programming
# 3            2  Programming
# 4            1      Physics
# 5            1         Math
# 6           13         Math
# 7           13  Programming
# 8           13      Physics
# 9            2         Math
# 10           1         Math

# %%
b=student_subject_df.merge(students_df,left_on='student_id',right_on='student_id',how='outer')

# %%
b
# Out:
#     student_id subject_name student_name
# 0            1         Math        Alice
# 1            1      Physics        Alice
# 2            1  Programming        Alice
# 3            1      Physics        Alice
# 4            1         Math        Alice
# 5            1         Math        Alice
# 6            2  Programming          Bob
# 7            2         Math          Bob
# 8            6          NaN         Alex
# 9           13         Math         John
# 10          13  Programming         John
# 11          13      Physics         John

# %%
b.groupby(['subject_name','student_name']).count().reset_index().sort_values(by='student_name')
# Out:
#   subject_name student_name  student_id
# 0         Math        Alice           3
# 3      Physics        Alice           2
# 5  Programming        Alice           1
# 1         Math          Bob           1
# 6  Programming          Bob           1
# 2         Math         John           1
# 4      Physics         John           1
# 7  Programming         John           1

# %% [markdown]
# #Write a solution to find managers with at least five direct reports.

# %%
import pandas as pd
data = {
    "id": [101, 102, 103, 104, 105, 106],
    "name": ["John", "Dan", "James", "Amy", "Anne", "Ron"],
    "department": ["A", "A", "A", "A", "A", "B"],
    "managerId": [None, 101, 101, 101, 101, 101]
}
df = pd.DataFrame(data)
df
# Out:
#     id   name department  managerId
# 0  101   John          A        NaN
# 1  102    Dan          A      101.0
# 2  103  James          A      101.0
# 3  104    Amy          A      101.0
# 4  105   Anne          A      101.0
# 5  106    Ron          B      101.0

# %%
manager_counts = df["managerId"].value_counts()
result = manager_counts[manager_counts >= 5].reset_index()
result.columns = ["id", "direct_reports"]
result
# Out:
#       id  direct_reports
# 0  101.0               5

# %% [markdown]
# #Write a solution to find the names of all the salespersons who did not have any orders related to the company with the name "RED".

# %%
data = {
    "sales_id": [1, 2, 3, 4, 5],
    "name": ["John", "Amy", "Mark", "Pam", "Alex"],
    "salary": [100000, 12000, 65000, 25000, 5000],
    "commission_rate": [6, 5, 12, 25, 10],
    "hire_date": ["4/1/2006", "5/1/2010", "12/25/2008", "1/1/2005", "2/3/2007"]
}
df1 = pd.DataFrame(data)
df1
# Out:
#    sales_id  name  salary  commission_rate   hire_date
# 0         1  John  100000                6    4/1/2006
# 1         2   Amy   12000                5    5/1/2010
# 2         3  Mark   65000               12  12/25/2008
# 3         4   Pam   25000               25    1/1/2005
# 4         5  Alex    5000               10    2/3/2007

# %%
data = {
    "com_id": [1, 2, 3, 4],
    "name": ["RED", "ORANGE", "YELLOW", "GREEN"],
    "city": ["Boston", "New York", "Boston", "Austin"]
}
df2 = pd.DataFrame(data)
df2
# Out:
#    com_id    name      city
# 0       1     RED    Boston
# 1       2  ORANGE  New York
# 2       3  YELLOW    Boston
# 3       4   GREEN    Austin

# %%
data = {
    "order_id": [1, 2, 3, 4],
    "order_date": ["1/1/2014", "2/1/2014", "3/1/2014", "4/1/2014"],
    "com_id": [3, 4, 1, 1],
    "sales_id": [4, 5, 1, 4],
    "amount": [10000, 5000, 50000, 25000]
}

df3 = pd.DataFrame(data)
df3
# Out:
#    order_id order_date  com_id  sales_id  amount
# 0         1   1/1/2014       3         4   10000
# 1         2   2/1/2014       4         5    5000
# 2         3   3/1/2014       1         1   50000
# 3         4   4/1/2014       1         4   25000

# %%
v=df2.merge(df3,on='com_id',how='outer')

# %%
v
# Out:
#    com_id    name      city  order_id order_date  sales_id   amount
# 0       1     RED    Boston       3.0   3/1/2014       1.0  50000.0
# 1       1     RED    Boston       4.0   4/1/2014       4.0  25000.0
# 2       2  ORANGE  New York       NaN        NaN       NaN      NaN
# 3       3  YELLOW    Boston       1.0   1/1/2014       4.0  10000.0
# 4       4   GREEN    Austin       2.0   2/1/2014       5.0   5000.0

# %%
df1
# Out:
#    sales_id  name  salary  commission_rate   hire_date
# 0         1  John  100000                6    4/1/2006
# 1         2   Amy   12000                5    5/1/2010
# 2         3  Mark   65000               12  12/25/2008
# 3         4   Pam   25000               25    1/1/2005
# 4         5  Alex    5000               10    2/3/2007

# %%
new_df=v.merge(df1,on='sales_id',how='left')
new_df
# Out:
#    com_id  name_x      city  order_id order_date  sales_id   amount name_y  \
# 0       1     RED    Boston       3.0   3/1/2014       1.0  50000.0   John
# 1       1     RED    Boston       4.0   4/1/2014       4.0  25000.0    Pam
# 2       2  ORANGE  New York       NaN        NaN       NaN      NaN    NaN
# 3       3  YELLOW    Boston       1.0   1/1/2014       4.0  10000.0    Pam
# 4       4   GREEN    Austin       2.0   2/1/2014       5.0   5000.0   Alex
#
#      salary  commission_rate hire_date
# 0  100000.0              6.0  4/1/2006
# 1   25000.0             25.0  1/1/2005
# 2       NaN              NaN       NaN
# 3   25000.0             25.0  1/1/2005
# 4    5000.0             10.0  2/3/2007

# %%
# Write a solution to find the names of all the salespersons who did not have any orders related to the company with the name "RED".
new_df[new_df['name_x']!='RED']['name_y']
# Out:
# 2     NaN
# 3     Pam
# 4    Alex
# Name: name_y, dtype: object
